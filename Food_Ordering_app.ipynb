# %%
import re


class Food_Application:

    # main code
    def __init__(self):
        self.foodapp_name = "Feast_restaurant"
        self.admin_purpose = {}                 #it is for admin register and login
        self.user_purpose = {}                  #it is for user register and login
        self.food = {}                          #food item should be add by admin only
        self.food_id = len(self.food) + 1       #it add food item to previous dictionary
        self.foodcart = {}                      
        self.order_history = len(self.foodcart) + 1
        self.order = {}

    def admin_register(self):
        '''  Registration for Admin'''
        try:
            self.name = input("Enter Your Full Name\n")
            while True:
                ph_number = input("Enter your phone number\n")
                m=re.fullmatch("[6-9][0-9]{9}",ph_number)
                if m!=None:
                     self.phone_number=ph_number
                     break
                else:
                  print("invalid number,The number should be start from 6 to 9 of 10 digits")
       
                        
            while True:
                
                email = input("Enter Your Email Id here\n")
                self.email=email
                if re.fullmatch('[a-z0-9@.]{10,30}', email):
                  pass
                else:
                   print("invalid,please enter the valid gmail id")
                                      
                c=re.finditer("@",email)
                for match in c:
                   y = match.start()
                if email[y+1:] =="gmail.com":
                   print(email)
                   break
                
                else:
                  print("Please enter valid gmail id")
                
            while True:
                print("Password must Contain min 10 characters\n")
                password = input("Enter Your Password Here\n")
                ps=re.fullmatch('[A-Za-z0-9@#$%^&+=]{10,20}', password)
                if ps!=None:
                  self.password=password
                  break
                else:
                  print("please enter valid password")
          
                
            self.admin_details = {"NAME": self.name, "EMAIL": self.email, "NUMBER": self.phone_number,"PASSWORD": self.password}  #  Admin details
            print("    !!!CONGRATULATIONS!!!_________Account is Created Succsessfully_________")
            
        except Exception as e:
            print('!! Something Went Wrong ,try again !!\n')

    def admin_login(self,Admin_login,Password):
      '''Login with resitered details'''
      if self.admin_details["EMAIL"] == Admin_login or self.admin_details["NAME"] == Admin_login:
          if self.admin_details["PASSWORD"] == Password:
            print("!!!!!Login successfully!!!!!")
            print(f'Welocme {self.admin_details["NAME"]}')
            return True
          else:
            print("Check password again")
      else:
          print("Enter the registered username or phonenumber or email_id")    

    def add_fooditem(self, name, quantity, price, discount, stock):
        '''add food items to the list '''
        self.item = {'NAME': name, 'QUANTITY': quantity, 'PRICE': price, 'DISCOUNT': discount,
                     'STOCK': stock} 
        self.foodid = len(self.food) + 1  
        self.food[self.foodid] = self.item
        print('\n** Item Added Successfully **\n')

    def edit_fooditem(self, foodid):
        '''You can edit available food items from list Here'''
        try:
            if len(self.food) > 0:                        # to check if list is empty or not
                print("\n1.Edit Food Name\n2.Edit Quantity of food\n3.Edit Price\n4.Edit Discount\n5.Edit stock")
                while True:
                    Echoice = int(input("\nEnter Choice From Above List\n"))
                    if Echoice == 1:
                        new_name = input("Enter New Food Name\n")
                        self.food[foodid]['NAME'] = new_name            # to edit old dict values with new  dict values
                        print('\n!! Name updated Successfully !!')
                        break
                    elif Echoice == 2:
                        new_qun = input("Enter New Quantity\n")
                        self.food[foodid]['QUANTITY'] = new_qun
                        print('\n!! Quantity updated Successfully !!')
                        break
                    elif Echoice == 3:
                        while True:
                            new_PRICE = input("Enter New Price\n")
                            if new_PRICE.isnumeric() == True:
                                new_PRICE = int(new_PRICE)
                                self.food[foodid]['PRICE'] = new_PRICE
                                print('\n!! Price updated Successfully !!')
                                break
                            else:
                                print("Enter only numeric value")
                    elif Echoice == 4:
                        while True:
                            new_Discount = input("Enter New Discount\n")
                            if new_Discount.isnumeric() == True:
                                new_Discount = int(new_Discount)
                                self.food[foodid]['DISCOUNT'] = new_Discount
                                print('\n!! Discount updated Successfully !!')
                                break
                            else:
                                print("Enter only numeric value")
                    elif Echoice == 5:
                        while True:
                            new_stock = input("Entre New stock\n")
                            if new_stock.isnumeric() == True:
                                new_stock = float(new_stock)
                                self.food[foodid]['STOCK'] = new_stock
                                print('\n!! stock updated Successfully !!')
                                break
                            else:
                                print("Entre only numeric value")
                    else:
                        print("Invalid Input\n")
            else:
                print('\nNO FOOD ITEMS AVAILABLE NOW FOR EDIT\n')
        except Exception as e:
            print('!! ENTERED INVALID FOOD ITEM  !!\n')

    def view_fooditem(self):
        '''List of Food Items in this Restaurant'''
        if len(self.food) != 0:
            for i in self.food:
                print(
                    f"ID: {i} | NAME: {self.food[i]['NAME']} | PRICE: {self.food[i]['PRICE']} | DISCOUNT: {self.food[i]['DISCOUNT']} | STOCK: {self.food[i]['STOCK']}")
        else:
            print('\n_________NO FOOD ITEMS AVAILABE NOW_______\n')

    def delete_fooditem(self, foodid):
        '''Delete food items from list'''
        if len(self.food) != 0:
            if foodid in self.food.keys():
                del self.food[foodid]
                print('\n!!Deleted Successfully !!\n')
            else:
                print('Invalid Food ID\n')
        else:
            print('\nNo food Items Availble  Now For  Delete')

    # user function

    def user_register(self):  # using "u" to indicate user
        '''USER REGISTRATION FUNCTION'''
        try:          
            self.uname = input("Enter Your Full Name = \n")
            while True:
                uphone = input("Enter Your Phone Number\n")  
                n=re.fullmatch("[6-9][0-9]{9}",uphone)
                if n!=None:
                     self.uphone=uphone
                     break
                else:
                  print("invalid number,The number should be start from 6 to 9 of 10 digits")
                
            while True:
                
                uemail = input("Enter Your Email  here= \n")
                
                self.uemail=uemail
                if re.fullmatch('[a-z0-9@.]{10,30}', uemail):
                  pass
                else:
                   print("invalid,please enter the valid gmail id")
                   
                q=re.finditer("@",uemail)
                for match in q:
                   j = match.start()
                if uemail[j+1:] =="gmail.com":
                   print(uemail)
                   break
                
                else:
                  print("please enter valid gmailid")   
                
            while True:
                print("Password must Contain min 10 characters")
                upassword = input("Enter Your Password Here\n")
                p_s=re.fullmatch('[A-Za-z0-9@#$%^&+=]{10,20}',upassword)
                if p_s!=None:
                  self.upassword=upassword
                  break
                else:
                  print("please enter valid password")
                
            self.address = input("Enter Your  Address or location \n")

            self.user_details = {"NAME": self.uname, "PHONE": self.uphone, "EMAIL": self.uemail, "PASSWORD": self.upassword, "ADDRESS": self.address}  #user details
            print("    !!!CONGRATULATIONS!!! _____________ Account Created Succsessfully ___________")

        except Exception as e:
            print('!! Something Went Wrong ,Try again !!\n')

    def user_login(self,user_input,upassword):
        ''' LOGIN WITH RESGISTERED DETAILS'''

        if len(self.user_details) > 0:
          if self.user_details["EMAIL"] == user_input or self.user_details["NAME"] == user_input:
            if self.user_details["PASSWORD"] == upassword:
                print("!!!!!Login successfully!!!!!")
                print(f"Welcome {self.user_details['NAME']}")
                return True
            else:
                print("check the password again")  
          else:
                print("Check email or username or phone number\n")
        else:
          print("This emaild or username is not registered with us ") 
           
    def user_show_foodlist(self):
        '''Food item available '''
        if len(self.food) != 0:
            for i in self.food:
                print(
                    f"ID: {i} | NAME: {self.food[i]['NAME']} | PRICE: {self.food[i]['PRICE']} | QUANTITY: {self.food[i]['QUANTITY']}")
        else:
            print("Nothing To Show Here\n")

    def show_userprofile(self):
        '''User details'''
        print(
            f" Name= {self.user_details['NAME']}\n Phone Number= {self.user_details['PHONE']}\n EMAIL= {self.user_details['EMAIL']}\n ADDRESS= {self.user_details['ADDRESS']}\n ")

    def update_UserProfile(self, upassword):
                  
        '''update profile info'''
        try:
            
            if self.user_details["PASSWORD"] == upassword:
                while True:
                    print(" 1.Update Your Name\n 2.Update Your Phone Number\n 3.Upadte Your Email\n 4.Update Your Address\n 5.Update Your Password\n 6.Back")
                    upchoice = input('Enter Your Choice\n')
                    if upchoice == '1':
                        print(f"Your Currunt Profile Name is{self.user_details['NAME']}")
                        newname = input("Enter new Name \n")
                        self.user_details['NAME'] = newname
                        print(" Name Updated")
                    elif upchoice == '2':
                        print(f"Your Currunt Phone Number is{self.user_details['PHONE']}")
                        while True:
                            newnum = input("Enter new Number \n")
                            num=re.fullmatch("[6-9][0-9]{9}",newnum)
                            if num!=None:
                              self.user_details['PHONE'] = newnum
                              print("Phone Number Updated")
                              break
                            else:
                              print("invalid number,The number should be start from 6 to 9 of 10 digits")
                            
                    elif upchoice == '3':
                        print(f"Your Currunt Email is{self.user_details['EMAIL']}")
                        while True:
                            
                            newemail = input("Enter Your Email  here: \n")
                            self.user_details['EMAIL'] = newemail
                            if re.fullmatch('[a-z0-9@.]{10,30}', newemail):
                              pass
                            else:
                              print("invalid,please enter the valid gmail id")
                            
                            w=re.finditer("@",newemail)
                            for match in w:
                             v = match.start()
                            if newemail[v+1:] =="gmail.com":
                             print("updated")
                             break
                            
                            else:
                               print("Please enter valid gmail id")
                            
                    elif upchoice == '4':
                        print(f"Your Currunt Address is{self.user_details['ADDRESS']}")
                        newadd = input("Enter the new address or Location \n")
                        self.user_details['ADDRESS'] = newadd
                        print("Address Upadted")
                    elif upchoice == '5':
                        print("Password must Contain min 10 characters")
                        while True:
                            newpass = input("Enter new Password \n")
                            np_s=re.fullmatch('[A-Za-z0-9@#$%^&+=]{10,20}',newpass)
                            if np_s!=None:
                              self.user_details['PASSWORD'] = newpass
                              print("Password Updated")
                              break
                            else:
                              print("please enter valid password")
                            
                    elif upchoice == '6':
                        break
                    else:
                        print("PLEASE GIVE VALID INPUT")
            else:
                print("Wrong Password Enter Valid Password To continue")
        except Exception as e:
            print('!! Something Went Wrong ,try again !!\n')

    def add_foodcart(self, food_id):
        '''function to add food item in cart'''
        food_id = int(food_id)
        if food_id in self.food.keys():
            if self.food[food_id]['STOCK'] > 0:
                if food_id in self.foodcart.keys():
                    self.foodcart[food_id]["QTY"] = self.foodcart[food_id]["QTY"] + 1
                    self.foodcart[food_id]['TOTAL'] = self.foodcart[food_id]['TOTAL'] + self.food[food_id]['PRICE']
                    self.foodcart[food_id] = {"NAME": self.food[food_id]['NAME'], "PRICE": self.food[food_id]['PRICE'],
                                              "QTY": self.foodcart[food_id]["QTY"],
                                              "TOTAL": self.foodcart[food_id]['TOTAL']}
                    self.food[food_id]['STOCK'] = self.food[food_id]['STOCK'] - 1
                else:
                    self.foodcart[food_id] = {"NAME": self.food[food_id]['NAME'], "PRICE": self.food[food_id]['PRICE'],
                                              "QTY": 1, "TOTAL": self.food[food_id]['PRICE']}
                    self.food[food_id]['STOCK'] = self.food[food_id]['STOCK'] - 1
            else:
                print(F" {self.food[food_id]['NAME']} Not Available At This Moment")
        else:
            print(f' You Entered {food_id} is Wrong ID')

    def show_cart(self):
        '''show cart items to user'''
        if len(self.foodcart) > 0:
            for i in self.foodcart:
                print(
                    f" ID={i} | NAME: {self.foodcart[i]['NAME']} | PRICE: {self.foodcart[i]['PRICE']} | QUANTITY : {self.foodcart[i]['QTY']} | TOTAL : {self.foodcart[i]['TOTAL']}")
        else:
            print("cart is Empty ,,___now add something___")

    def orderhistory(self):
        '''orders history '''
        for i in self.foodcart.keys():
            self.order[self.order_history] = {"NAME": self.foodcart[i]['NAME'], "PRICE": self.foodcart[i]['PRICE'],
                                           "QTY": 1, "TOTAL": self.foodcart[i]['PRICE']}
            self.order_history = self.order_history + 1

    def show_orderhistory(self):
        '''all orders history '''
        if len(self.order) > 0:
            for i in self.order:
                print(
                    f" Id: {i} | NAME: {self.order[i]['NAME']} | PRICE: {self.order[i]['PRICE']} | QTY: {self.order[i]['QTY']} | TOTAL: {self.order[i]['TOTAL']}")
        else:
            print("Nothing to show ,*** Order Something First***")

    def delete_cartitem(self, foodid):
        ''' delete food items from  cart list'''
        if len(self.foodcart) != 0:
            if foodid in self.foodcart.keys():
                self.food[foodid]['STOCK'] = self.food[foodid]['STOCK'] + self.foodcart[foodid]['QTY']
                del self.foodcart[foodid]
                print('\n!!Deleted Successfully !!\n')
            else:
                print('Invalid Food ID\n')
        else:
            print('\nNo Food Items Availble  Now For  Delete')

def Driver_code():
      #driver code to run main functiom
      try:
        obj= Food_Application()
        while True:
            print(f'Welcome to {obj.foodapp_name} \n')
            print("__Order and Enjoy the Feast at your doorstep__")
            print("Please Enter Your Selection from Below Options\n")
            print('1. ADMIN')
            print('2. USER')
            print('3. CLOSE\n')
            Dinput = input('Enter Your Selection : \n')
            if Dinput == '1':
                while True:
                    print('\n1. ADMIN REGISTER')
                    print('2. ADMIN LOGIN')
                    print('3. BACK')
                    Dinput2 = input('Enter Your Selection : \n')
                    if Dinput2 == '1':
                        print(obj.admin_register.__doc__)
                        obj.admin_register()
                    elif Dinput2 == '2':
                        print(obj.admin_login.__doc__)
                        Admin_login = input('ENTER YOUR REGISTRED EMAIL OR NAME : \n')
                        password = input('REGISTRED ADMIN PASSWORD : \n')
                        if obj.admin_login(Admin_login, password):
                            while True:
                                print('1. Add new food item')
                                print('2. Edit food item')
                                print('3. View food item')
                                print('4. Delete food item')
                                print('5. Back')
                                X = input('Enter Your Selection : \n')
                                if X == '1':
                                    print(obj.add_fooditem.__doc__)
                                    name = input('Enter the food name : \n')
                                    quantity = input('Enter Updated Quantity like For eg, 100ml, 250gm, 4pieces etc : \n')
                                    while True:
                                        price = input('Enter Updated Price ₹ : \n')
                                        if price.isnumeric() == True:
                                            price = int(price)
                                            break
                                        else:
                                            print("Only numeric value will execpted")
                                    while True:
                                        discount = input('Enter Updated Discount in ₹ : ')
                                        if discount.isnumeric() == True or discount.isdecimal() == True:
                                            discount = float(discount)
                                            break
                                        else:
                                            print("Only numeric value will execpted")
                                    while True:
                                        stock = input('Enter Updated Stock : ')
                                        if stock.isnumeric() == True:
                                            stock = int(stock)
                                            break
                                        else:
                                            print("Only numeric value will execpted")
                                    obj.add_fooditem(name, quantity, price, discount, stock)
                                elif X == '2':
                                    print("List Of Food Items")
                                    obj.view_fooditem()
                                    foodid = int(input('Enter food id : '))
                                    obj.edit_fooditem(foodid)
                                elif X == '3':
                                    obj.view_fooditem()
                                elif X == '4':
                                    foodid = int(input('Enter food id : '))
                                    obj.delete_fooditem(foodid)
                                    print("Updated Food Items")
                                    obj.view_fooditem()
                                elif X == '5':
                                    break
                                else:
                                    print('Invalid option\n')
                        else:
                            print('INVALID EMAIL OR PASSOWRD')
                    elif Dinput2 == '3':
                        break
                    else:
                        print('INVALID OPTION')
            elif Dinput == '2':
                while True:
                    print('\n1. USER REGISTER')
                    print('2. USER LOGIN')
                    print('3. BACK')
                    uinput = input('Enter Your Selection : ')
                    if uinput == '1':
                        obj.user_register()
                    elif uinput == '2':
                      print(obj.user_login.__doc__)
                      user_input = input("Enter Your Registerd Email or username ")
                      upassword = input("Enter Your Password ")
                      if obj.user_login(user_input,upassword):
                        while True:
                                print('1. Place Order')
                                print('2. Show Order History')
                                print('3. Show Profile Details')
                                print('4. Edit Profile Details')
                                print('5. Back')
                                uinput2 = input("Enter Your Choice")
                                if uinput2 == '1':
                                    while True:
                                        print('1. Show Food Items')
                                        print('2. Add Food Items In Your cart')
                                        print('3. Delete Food Items From Your cart')
                                        print('4. Show cart')
                                        print('5. Back')
                                        uinput3 = input("Enter Your Choice\n")
                                        if uinput3 == '1':
                                            obj.view_fooditem()
                                        elif uinput3 == '2':
                                            if len(obj.food) > 0:
                                                food_id = input("Enter food Id Seprated By comma ex: 1,2,3,4,4,4 \n")
                                                for i in food_id:
                                                    if i.isnumeric() == True:
                                                        obj.add_foodcart(i)
                                                    else:
                                                        pass
                                                while True:
                                                    print("1. Show cart\n2. Place Order\n3.Back ")
                                                    oinput = input("Enter Your Choice \n")
                                                    if oinput == "1":
                                                        obj.show_cart()
                                                    if oinput == "2":
                                                        if len(obj.foodcart) > 0:
                                                            print("We are preparing Your Order. ")
                                                            print(
                                                                "After Ready Your Order We Will be delivered at Your Location ")
                                                            print(f"Address= {obj.user_details['ADDRESS']}")
                                                            obj.order_history()
                                                            obj.foodcart = {}
                                                            break
                                                        else:
                                                            print("nothing is added in cart to place your order")
                                                    elif oinput == "3":
                                                        break
                                                    else:
                                                        print("Please Give Correct Input")
                                            else:
                                                print("No Items Are Available At This Moment __Please Visit again__.")
                                        elif uinput3 == '3':
                                            if len(obj.foodcart) > 0:
                                                foodid = int(input('Enter food id : '))
                                                obj.delete_cartitem(foodid)
                                                print("Updated Food Items")
                                                obj.show_cart()
                                            else:
                                                print("Nothing to Remove,The cart is empty")
                                        elif uinput3 == '4':
                                            obj.show_cart()
                                            if len(obj.foodcart) > 0:
                                                while True:
                                                    print("1. Place Order\n2.Back ")
                                                    oinput = input("Enter Your Choice \n")
                                                    if oinput == "1":
                                                        print("We are preparing Your Order. ")
                                                        print(
                                                            "After Ready Your Order We Will be delivered at Your Location ")
                                                        print(f"Address= {obj.user_details['ADDRESS']}")
                                                        obj.orderhistory()
                                                        obj.foodcart = {}
                                                        break
                                                    elif oinput == "2":
                                                        break
                                                    else:
                                                        print("Invalid Option")
                                            else:
                                                print("cart Is Empty Please Add Something...")
                                        elif uinput3 == "5":
                                            break
                                elif uinput2 == '2':
                                    obj.show_orderhistory()
                                elif uinput2 == '3':
                                    obj.show_userprofile()
                                elif uinput2 == '4':
                                    upassword = input("Entre Your Password ")
                                    obj.update_UserProfile(upassword)
                                elif uinput2 == "5":
                                    break
                                else:
                                    print("PLEASE GIVE VALID INPUT")
                        else:
                              print("Wrong Id OR Password")
                    elif uinput == '3':
                        break
                    else:
                        print("Enter Valid Input")
            elif Dinput == '3':
                break
            else:
                print('Please enter again')
                
      except Exception as e:
            print('!! Something Went Wrong ,____please Try!!\n')

if __name__ == "__main__":
    Driver_code()

print('THANK YOU VISIT AGAIN :')
# Out:
# Welcome to Feast_restaurant
#
# __Order and Enjoy the Feast at your doorstep__
# Please Enter Your Selection from Below Options
#
# 1. ADMIN
# 2. USER
# 3. CLOSE
#
# Enter Your Selection :
# 2
#
# 1. USER REGISTER
# 2. USER LOGIN
# 3. BACK
# Enter Your Selection : saro
# Enter Valid Input
#
# 1. USER REGISTER
# 2. USER LOGIN
# 3. BACK
# Enter Your Selection : 8989898898
# Enter Valid Input
#
# 1. USER REGISTER
# 2. USER LOGIN
# 3. BACK
# Enter Your Selection : 1
# Enter Your Full Name =
# saro
# Enter Your Phone Number
# 9898989898
# Enter Your Email  here=
# saro@gmail.com
# saro@gmail.com
# Password must Contain min 10 characters
# Enter Your Password Here
# SAro@131313
# Enter Your  Address or location
# salem
#     !!!CONGRATULATIONS!!! _____________ Account Created Succsessfully ___________
#
# 1. USER REGISTER
# 2. USER LOGIN
# 3. BACK
# Enter Your Selection : 2
#  LOGIN WITH RESGISTERED DETAILS
# Enter Your Registerd Email or username saro
# Enter Your Password SAro@131313
# ...
